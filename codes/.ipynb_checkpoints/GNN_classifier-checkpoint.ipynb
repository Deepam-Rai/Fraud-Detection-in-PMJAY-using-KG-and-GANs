# %%
from PyNeFrauds.Globals import neo4jHandler
from PyNeFrauds.nn import EmbedFetcher, PyGDataWrapper

# %%
neo4jHandler.set_credentials("bolt://localhost:11003", "neo4j","password")

embedFetcher = EmbedFetcher(embedProperty="GraphSage", uniqueID='project_id', target="fraud")

embedFetcher.fetchData()

dWrap = PyGDataWrapper()
dWrap.from_embed_fetcher(embedFetcher)

dWrap.show_data_info()
# Out:
# Number of nodes: 3860
# Number of features: 7
# Has isolated nodes: False

# %%
from collections import OrderedDict
from PyNeFrauds.nn import NNModel, train, ConfusionMatrix
import torch_geometric.nn as tgnn
import torch.nn as tnn

# %%
modules = OrderedDict({
    'GCN1' : tgnn.GCNConv(7, 32),
    'relu1': tnn.ReLU(),
    'linear2': tnn.Linear(32,2),
    'softmax': tnn.Softmax(dim=1)
})
model = NNModel(modules=modules)

dWrap.set_train_mask(frac=0.2)

model, losses = train(model=model, data=dWrap.data, n_epoch=50)

ConfusionMatrix(model=model, data=dWrap.data, use_test_mask=True)
# Out:
# epoch: 0/50 	 loss:0.691
# epoch: 1/50 	 loss:0.686
# epoch: 2/50 	 loss:0.683
# epoch: 3/50 	 loss:0.681
# epoch: 4/50 	 loss:0.679
# epoch: 5/50 	 loss:0.677
# epoch: 6/50 	 loss:0.674
# epoch: 7/50 	 loss:0.672
# epoch: 8/50 	 loss:0.669
# epoch: 9/50 	 loss:0.666
# epoch: 10/50 	 loss:0.664
# epoch: 11/50 	 loss:0.661
# epoch: 12/50 	 loss:0.659
# epoch: 13/50 	 loss:0.656
# epoch: 14/50 	 loss:0.653
# epoch: 15/50 	 loss:0.650
# epoch: 16/50 	 loss:0.647
# epoch: 17/50 	 loss:0.644
# epoch: 18/50 	 loss:0.641
# epoch: 19/50 	 loss:0.638
# epoch: 20/50 	 loss:0.635
# epoch: 21/50 	 loss:0.633
# epoch: 22/50 	 loss:0.630
# epoch: 23/50 	 loss:0.628
# epoch: 24/50 	 loss:0.626
# epoch: 25/50 	 loss:0.624
# epoch: 26/50 	 loss:0.622
# epoch: 27/50 	 loss:0.620
# epoch: 28/50 	 loss:0.618
# epoch: 29/50 	 loss:0.617
# epoch: 30/50 	 loss:0.616
# epoch: 31/50 	 loss:0.615
# epoch: 32/50 	 loss:0.614
# epoch: 33/50 	 loss:0.613
# epoch: 34/50 	 loss:0.613
# epoch: 35/50 	 loss:0.612
# epoch: 36/50 	 loss:0.612
# epoch: 37/50 	 loss:0.611
# epoch: 38/50 	 loss:0.611
# epoch: 39/50 	 loss:0.611
# epoch: 40/50 	 loss:0.611
# epoch: 41/50 	 loss:0.611
# epoch: 42/50 	 loss:0.611
# epoch: 43/50 	 loss:0.611
# epoch: 44/50 	 loss:0.611
# epoch: 45/50 	 loss:0.611
# epoch: 46/50 	 loss:0.611
# epoch: 47/50 	 loss:0.611
# epoch: 48/50 	 loss:0.611
# epoch: 49/50 	 loss:0.611
#               precision    recall  f1-score   support
#
#            0       0.65      0.77      0.71       395
#            1       0.70      0.57      0.63       377
#
#     accuracy                           0.67       772
#    macro avg       0.68      0.67      0.67       772
# weighted avg       0.68      0.67      0.67       772
